# %%
print ('hello, world!')
# Out:
# hello, world!

# %%
print ('harshini')
# Out:
# harshini

# %%
2+3
# Out:
# 5

# %%
x = 5

# %%
y = 2.34

# %%
str='harshini'

# %%
x = str(3)
y = int(3)
z = float(3)
print (x,y,z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-87d28043285d> in <cell line: 1>()
# ----> 1 x = str(3)
#       2 y = int(3)
#       3 z = float(3)
#       4 print (x,y,z)
#
# TypeError: 'str' object is not callable

# %%
x = 5
y = "john"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
x = "harshini"
print(x)
x = "19"
print(x)
# Out:
# harshini
# 19

# %%
x, y, z = "orange" , "banana" , "cherry"
print(x)
print(y)
print(z)
# Out:
# orange
# banana
# cherry

# %%
x, y, z, a, b, c, d, e = "orange" , "banana" , "cherry" , "10" , "20" , "30" , "40" , "50"
print(x)
print(y)
print(z)
print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# orange
# banana
# cherry
# 10
# 20
# 30
# 40
# 50

# %%
x = y = z = "orange"
print(x)
print(y)
print(z)
# Out:
# orange
# orange
# orange

# %%
#list
fruits = ["apple" , "banana" , "cherry"]

# %%
#list
fruits = ["apple" , "banana" , "cherry"]
x = fruits
print(x)
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry']

# %%
#list
fruits = ("apple" , "banana" , "cherry")
x = fruits
print(x)
print(fruits)
# Out:
# ('apple', 'banana', 'cherry')
# ('apple', 'banana', 'cherry')

# %%
thistuple = ("apple" , "banana" , "cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
#list
fruits = {"apple" , "banana" , "cherry"}
x = fruits
print(x)
print(fruits)
# Out:
# {'banana', 'apple', 'cherry'}
# {'banana', 'apple', 'cherry'}

# %%
thisdict = {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
if 5 > 2:
  print("Five is greater than two!")
# Out:
# Five is greater than two!

# %%
if 5 > 2:
  print("Five is greater than two!")
  if 5 > 1:
    print("Five is greater than one!")
    if 8 > 1:
      print("Eight is greater than one!")
      if 8 > 2:
        print("Eight is greater than two!")
        if 8 > 3:
          print("Eight is greater than three!")
# Out:
# Five is greater than two!
# Five is greater than one!
# Eight is greater than one!
# Eight is greater than two!
# Eight is greater than three!

# %%
from binascii import b2a_hex
a = 33
b = 33
if b > a:
  print("b is greater than a")
  elif a == b2a_hex
